# %%
#PRACTICA 2
from math import *
import numpy as np
import pandas as pd

def f1(x):
  return (x**2)*(np.log(x))
def f2(x):
  return (x**3)+(2*x**2)
def f3(x):
  return (np.exp(x)-1)/sin(x)
def f4(x):
  return x*cos(x**2)

#METODO SIMPSON 1/3
def MS1_3(x,y,f):
  h=(y-x)/2
  x_1=x + h
  return (h/3)*(f(x) + 4*f(x_1) + f(y))

#METODO SIMPSON COMPUESTO
def MSC(x,y,n,f):
  c=0
  p=0
  h=(y-x)/n
  for r in range(1,n,2):
    c+=f(x+ r*h)

  for i in range(2,n,2):
     p+=f(x+ i*h)
  return (h/3)*(f(x) + 4*c + 2*p + f(y))

#ERRORES
def errabs(x,y):
  return abs(y-x)
def error(x,y):
  return abs((y-x)/y)

#impresiones
n1=4
n2=5
print("FUNCION 1")
print("valor real=",22.574279703891)
print("El area aproximada por  MS 1/3 de f1 es:",MS1_3(1,4,f1))
print("El error absuluto es: ", errabs(MS1_3(1,4,f1),22.574279703891))
print("El error relativo es: ", error(MS1_3(1,4,f1),22.574279703891),"\n")
print("El area aproximada por  Simpson compuesto n=", n1," de f1 es:",MSC(1,4,n1,f1))
print("El error absuluto es: ", errabs(MSC(1,4,n1,f1),22.574279703891))
print("El error relativo es: ", error(MSC(1,4,n1,f1),22.574279703891),"\n")
print("El area aproximada por  Simpson compuesto n=", n2," de f1 es:",MSC(1,4,n2,f1))
print("El error absuluto es: ", errabs(MSC(1,4,n2,f1),22.574279703891))
print("El error relativo es: ", error(MSC(1,4,n2,f1),22.574279703891),"\n")

print("FUNCION 2")
print("valor real=",1.3333333)
print("El area aproximada por  MS 1/3 de f2 es:",MS1_3(-1,1,f2))
print("El error absuluto es: ", errabs(MS1_3(-1,1,f2),1.3333333))
print("El error relativo es: ", error(MS1_3(-1,1,f2),1.33333333),"\n")

print("El area aproximada por   Simpson compuesto n=", n1," de f2 es:",MSC(-1,1,n1,f2))
print("El error absuluto es: ", errabs(MSC(-1,1,n1,f2),1.3333333))
print("El error relativo es: ", error(MSC(-1,1,n1,f2),1.33333333),"\n")

print("El area aproximada por   Simpson compuesto n=", n2," de f2 es:",MSC(-1,1,n2,f2))
print("El error absuluto es: ", errabs(MSC(-1,1,n2,f2),1.3333333))
print("El error relativo es: ", error(MSC(-1,1,n2,f2),1.33333333),"\n")

print("FUNCION 3")
print("valor real=",2.4228504234839)
print("El area aproximada por  MS 1/3 de f3 es:",MS1_3(0.5,pi/2,f3))
print("El error absuluto es: ", errabs(MS1_3(0.5,pi/2,f3),2.4228504234839))
print("El error relativo es: ", error(MS1_3(0.5,pi/2,f3),2.4228504234839),"\n")

print("El area aproximada por  Simpson compuesto n=", n1," de f2 es:",MSC(0.5,pi/2,n1,f3))
print("El error absuluto es: ", errabs(MSC(0.5,pi/2,n1,f3),2.4228504234839))
print("El error relativo es: ", error(MSC(0.5,pi/2,n1,f3),2.4228504234839),"\n")
print("El area aproximada por Simpson compuesto n=", n2," de f2 es:",MSC(0.5,pi/2,n2,f3))
print("El error absuluto es: ", errabs(MSC(0.5,pi/2,n2,f3),2.4228504234839))
print("El error relativo es: ", error(MSC(0.5,pi/2,n2,f3),2.4228504234839),"\n")

print("FUNCION 4")
print("valor real=",-0.2151506084997)
print("El area aproximada por  MS 1/3 de f4 es:",MS1_3(0,pi,f4))
print("El error absuluto es: ", errabs(MS1_3(0,pi,f4),-0.2151506084997))
print("El error relativo es: ", error(MS1_3(0,pi,f4),-0.2151506084997),"\n")
print("El area aproximada por  Simpson compuesto n=", n1," de f2 es:",MSC(0,pi,n1,f4))
print("El error absuluto es: ", errabs(MSC(0,pi,n1,f4),-0.2151506084997))
print("El error relativo es: ", error(MSC(0,pi,n1,f4),-0.2151506084997),"\n")
print("El area aproximada por  Simpson compuesto n=", n2," de f2 es:",MSC(0,pi,n2,f4))
print("El error absuluto es: ", errabs(MSC(0,pi,n2,f4),-0.2151506084997))
print("El error relativo es: ", error(MSC(0,pi,n2,f4),-0.2151506084997),"\n")
# Out:
# FUNCION 1
# valor real= 22.574279703891
# El area aproximada por  MS 1/3 de f1 es: 22.543989037386062
# El error absuluto es:  0.030290666504939168
# El error relativo es:  0.001341822060427387
#
# El area aproximada por  Simpson compuesto n= 4  de f1 es: 22.571952730997168
# El error absuluto es:  0.0023269728938331014
# El error relativo es:  0.00010308071505962665
#
# El area aproximada por  Simpson compuesto n= 5  de f1 es: 19.04167341832503
# El error absuluto es:  3.532606285565972
# El error relativo es:  0.15648810646025071
#
# FUNCION 2
# valor real= 1.3333333
# El area aproximada por  MS 1/3 de f2 es: 1.3333333333333333
# El error absuluto es:  3.3333333204765836e-08
# El error relativo es:  2.49999988003402e-09
#
# El area aproximada por   Simpson compuesto n= 4  de f2 es: 1.3333333333333333
# El error absuluto es:  3.3333333204765836e-08
# El error relativo es:  2.49999988003402e-09
#
# El area aproximada por   Simpson compuesto n= 5  de f2 es: 1.1178666666666668
# ...
